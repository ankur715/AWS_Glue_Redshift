# %%
import requests

url = "https://apidojo-forever21-v1.p.rapidapi.com/categories/v2/list"

headers = {
	"X-RapidAPI-Key": "2f16fd7b75msh78aedd85e4d98bep157157jsn36b644047edf",
	"X-RapidAPI-Host": "apidojo-forever21-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'menuItemList': [{'Depth': '1', 'Order': '0', 'Name': 'f21-storefront-catalog', 'NameKr': None, 'NameJp': None, 'NameCn': None, 'NameDe': None, 'NameEs': None, 'NameFr': None, 'NameIt': None, 'NameNl': None, 'NameFromDB': None, 'Brand': None, 'Category': 'root', 'GroupName': None, 'Key': 'root', 'ParentKey': '', 'HasLandingPage': False, 'LandingPageKey': None, 'LeftMenuKey': 'root', 'ShowsOnTopMenu': '1', 'ExclusivePage': None, 'ExclusiveOption': None, 'CssClass': None, 'UseAltName': None, 'ImageViewType': None, 'ImagePath': None, 'ShowOnApp': '1', 'UseBloomreachDynamicCategory': None, 'MenuType': None, 'ChildMenus': [{'Depth': '2', 'Order': None, 'Name': 'New', 'NameKr': None, 'NameJp': None, 'NameCn': None, 'NameDe': None, 'NameEs': None, 'NameFr': None, 'NameIt': None, 'NameNl': None, 'NameFromDB': None, 'Brand': None, 'Category': 'women_new_arrivals_clothing', 'GroupName': None, 'Key': 'root_new_arrivals_top_nav_alias', 'ParentKey': 'root', 'HasLandingPage': False, 'LandingPageK
# ...

# %%
df = response.json()
len(df)
# Out:
# 11

# %%
import pandas as pd
pd.json_normalize(df)
# Out:
#                                         menuItemList  result code  \
# 0  [{'Depth': '1', 'Order': '0', 'Name': 'f21-sto...    True   00
#
#   errorMessage errorDetails  \
# 0                      None
#
#                                        authorization customerId ReturnCode  \
# 0  Bearer eyJ0eXAiOiJKV1QiLCJraWQiOiJEMWhPUDdEODN...       None       None
#
#   ErrorMessage ReturnMessage sfccAuthorizations.authorizationForShopper  \
# 0         None          None
#
#             sfccAuthorizations.authorizationForOCAPI  \
# 0  Bearer eyJfdiI6IjEiLCJhbGciOiJIUzI1NiIsInR5cCI...
#
#             sfccAuthorizations.authorizationForOther  \
# 0  Bearer eyJ0eXAiOiJKV1QiLCJraWQiOiJEMWhPUDdEODN...
#
#    sfccAuthorizations.IsExpiredLogedToken sfccAuthorizations.refresh_token
# 0                                   False                             None

# %%
for i in df:
    print(i)
# Out:
# menuItemList
# result
# code
# errorMessage
# errorDetails
# authorization
# customerId
# sfccAuthorizations
# ReturnCode
# ErrorMessage
# ReturnMessage

# %%
len(df["menuItemList"][0])
# Out:
# 31

# %%
for i in df["menuItemList"][0]:
    print(i)
# Out:
# Depth
# Order
# Name
# NameKr
# NameJp
# NameCn
# NameDe
# NameEs
# NameFr
# NameIt
# NameNl
# NameFromDB
# Brand
# Category
# GroupName
# Key
# ParentKey
# HasLandingPage
# LandingPageKey
# LeftMenuKey
# ShowsOnTopMenu
# ExclusivePage
# ExclusiveOption
# CssClass
# UseAltName
# ImageViewType
# ImagePath
# ShowOnApp
# UseBloomreachDynamicCategory
# MenuType
# ChildMenus

# %%
df["menuItemList"][0].items()
# Out:
# dict_items([('Depth', '1'), ('Order', '0'), ('Name', 'f21-storefront-catalog'), ('NameKr', None), ('NameJp', None), ('NameCn', None), ('NameDe', None), ('NameEs', None), ('NameFr', None), ('NameIt', None), ('NameNl', None), ('NameFromDB', None), ('Brand', None), ('Category', 'root'), ('GroupName', None), ('Key', 'root'), ('ParentKey', ''), ('HasLandingPage', False), ('LandingPageKey', None), ('LeftMenuKey', 'root'), ('ShowsOnTopMenu', '1'), ('ExclusivePage', None), ('ExclusiveOption', None), ('CssClass', None), ('UseAltName', None), ('ImageViewType', None), ('ImagePath', None), ('ShowOnApp', '1'), ('UseBloomreachDynamicCategory', None), ('MenuType', None), ('ChildMenus', [{'Depth': '2', 'Order': None, 'Name': 'New', 'NameKr': None, 'NameJp': None, 'NameCn': None, 'NameDe': None, 'NameEs': None, 'NameFr': None, 'NameIt': None, 'NameNl': None, 'NameFromDB': None, 'Brand': None, 'Category': 'women_new_arrivals_clothing', 'GroupName': None, 'Key': 'root_new_arrivals_top_nav_alias', 'Pare
# ...

# %%
data_transformed = pd.DataFrame()
Depth = []
Order = []
Name = []
NameKr = []
NameJp = []
NameCn = []
NameDe = []
NameEs = []
NameFr = []
NameIt = []
NameNl = []
NameFromDB = []
Brand = []
Category = []
GroupName = []
Key = []
ParentKey = []
HasLandingPage = []
LandingPageKey = []
LeftMenuKey = []
ShowsOnTopMenu = []
ExclusivePage = []
ExclusiveOption = []
CssClass = []
UseAltName = []
ImageViewType = []
ImagePath = []
ShowOnApp = []
UseBloomreachDynamicCategory = []
MenuType = []
# ChildMenus  ## Nested
ChildMenus = []

### only combining the lists to iterate to avoid so many lines in the for loop below
### would append to list object directly, not cols loop like this, only testing here
cols = [Depth, Order, Name, NameKr, NameJp, NameCn, NameDe, NameEs, NameFr, NameIt, NameNl, 
        NameFromDB, Brand, Category, GroupName, Key, ParentKey, HasLandingPage, LandingPageKey,
        LeftMenuKey, ShowsOnTopMenu, ExclusivePage, ExclusiveOption, CssClass, UseAltName, 
        ImageViewType, ImagePath, ShowOnApp, UseBloomreachDynamicCategory, MenuType, ChildMenus]

# %%
len(list(df["menuItemList"][0].keys()))
# Out:
# 31

# %%
df["menuItemList"][0].get(lst_cols[0])
# Out:
# '1'

# %%
len(dct.get("ChildMenus"))
# Out:
# 8

# %%
dct.get("ChildMenus")[7].get("ChildMenus")
len(dct.get("ChildMenus")[7].get("ChildMenus"))
# Out:
# 6

# %%
lst_colnames = list(dct.keys())
dct.get("ChildMenus")[7].get("ChildMenus")[0].get(lst_colnames[30])
# Out:
# [{'Depth': '4',
#   'Order': None,
#   'Name': 'New To Sale',
#   'NameKr': None,
#   'NameJp': None,
#   'NameCn': None,
#   'NameDe': None,
#   'NameEs': None,
#   'NameFr': None,
#   'NameIt': None,
#   'NameNl': None,
#   'NameFromDB': None,
#   'Brand': None,
#   'Category': 'sale_newly_added',
#   'GroupName': None,
#   'Key': 'sale_featured_new_to_sale_nav_all',
#   'ParentKey': 'sale_featured',
#   'HasLandingPage': False,
#   'LandingPageKey': None,
#   'LeftMenuKey': 'new_to_sale_nav_all',
#   'ShowsOnTopMenu': '1',
#   'ExclusivePage': None,
#   'ExclusiveOption': None,
#   'CssClass': None,
#   'UseAltName': None,
#   'ImageViewType': None,
#   'ImagePath': None,
#   'ShowOnApp': '1',
#   'UseBloomreachDynamicCategory': None,
#   'MenuType': None,
#   'ChildMenus': None},
#  {'Depth': '4',
#   'Order': None,
#   'Name': 'View All Sale',
#   'NameKr': None,
#   'NameJp': None,
#   'NameCn': None,
#   'NameDe': None,
#   'NameEs': None,
#   'NameFr': None,
# ...

# %%
dct = df["menuItemList"][0]
lst_colnames = list(dct.keys())
# print(lst_colnames)
reformed_dct = {}
for i in range(len(dct)):
#     print(lst_colnames[i])
    if lst_colnames[i] == "ChildMenus":
        nested = dct.get("ChildMenus")
#         print(nested)
        for j in range(len(nested)):
#             print("----------------")
#             print(nested[j])
            for k,v in nested[j].items():
                reformed_dct[k] = v
    else:
        for key in lst_colnames:
            reformed_dct[key] = dct.get(key)

# %%
pd.json_normalize(reformed_dct)
# Out:
#   Depth Order  Name NameKr NameJp NameCn NameDe NameEs NameFr NameIt  ...  \
# 0     2  None  Sale   None   None   None   None   None   None   None  ...
#
#                                        ExclusivePage ExclusiveOption CssClass  \
# 0  https://production-na01-forever21.demandware.n...            None     None
#
#   UseAltName ImageViewType ImagePath ShowOnApp  UseBloomreachDynamicCategory  \
# 0       None          None      None         1                          None
#
#   MenuType                                         ChildMenus
# 0     None  [{'Depth': '3', 'Order': None, 'Name': 'Featur...
#
# [1 rows x 31 columns]

# %%
import csv
data = df["menuItemList"]
 
# now we will open a file for writing
data_file = open('data/testing_data_file.csv', 'w')
 
# create the csv writer object
csv_writer = csv.writer(data_file)
 
# Counter variable used for writing 
# headers to the CSV file
count = 0
 
for dat in data:
    if count == 0:
 
        # Writing headers of CSV file
        header = dat.keys()
        csv_writer.writerow(header)
        count += 1
 
    # Writing data of CSV file
    csv_writer.writerow(dat.values())
 
data_file.close()

# %%
data_file = pd.read_csv("data/testing_data_file.csv", encoding='cp1252')
data_file.shape
# Out:
# (1, 31)

# %%
data_file
# Out:
#    Depth  Order                    Name  NameKr  NameJp  NameCn  NameDe  \
# 0      1      0  f21-storefront-catalog     NaN     NaN     NaN     NaN
#
#    NameEs  NameFr  NameIt  ...  ExclusivePage  ExclusiveOption  CssClass  \
# 0     NaN     NaN     NaN  ...            NaN              NaN       NaN
#
#   UseAltName  ImageViewType ImagePath  ShowOnApp  \
# 0        NaN            NaN       NaN          1
#
#    UseBloomreachDynamicCategory  MenuType  \
# 0                           NaN       NaN
#
#                                           ChildMenus
# 0  [{'Depth': '2', 'Order': None, 'Name': 'New', ...
#
# [1 rows x 31 columns]

# %%
data_file.to_json("data/testing_data_file.json")

# %%
## S3 to create bucket and store
import boto3
access_key = pd.read_csv("../ankur_accessKeys_s3.csv")
sess = boto3.Session(region_name="us-east-2")
client = sess.client('s3',
                     aws_access_key_id=access_key["Access key ID"][0],
                     aws_secret_access_key=access_key["Secret access key"][0])
bucket_name = 'forever21etl'

# %%
client.create_bucket(Bucket=bucket_name,
    CreateBucketConfiguration={'LocationConstraint': 'us-east-2'})
# Out:
# {'ResponseMetadata': {'RequestId': 'SAJNJTWPKRKEY2SX',
#   'HostId': '3S1XhE/hvq+nNRVNRSNq08QiXZMrArUTV4D07eyJ1gkAEUSbTK/i3dqgEU03gQftVYuRx4mBxlk=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': '3S1XhE/hvq+nNRVNRSNq08QiXZMrArUTV4D07eyJ1gkAEUSbTK/i3dqgEU03gQftVYuRx4mBxlk=',
#    'x-amz-request-id': 'SAJNJTWPKRKEY2SX',
#    'date': 'Sun, 04 Feb 2024 00:16:02 GMT',
#    'location': 'http://forever21etl.s3.amazonaws.com/',
#    'server': 'AmazonS3',
#    'content-length': '0'},
#   'RetryAttempts': 0},
#  'Location': 'http://forever21etl.s3.amazonaws.com/'}

# %%
import json
json.dumps(response.json())
# Out:
# '{"menuItemList": [{"Depth": "1", "Order": "0", "Name": "f21-storefront-catalog", "NameKr": null, "NameJp": null, "NameCn": null, "NameDe": null, "NameEs": null, "NameFr": null, "NameIt": null, "NameNl": null, "NameFromDB": null, "Brand": null, "Category": "root", "GroupName": null, "Key": "root", "ParentKey": "", "HasLandingPage": false, "LandingPageKey": null, "LeftMenuKey": "root", "ShowsOnTopMenu": "1", "ExclusivePage": null, "ExclusiveOption": null, "CssClass": null, "UseAltName": null, "ImageViewType": null, "ImagePath": null, "ShowOnApp": "1", "UseBloomreachDynamicCategory": null, "MenuType": null, "ChildMenus": [{"Depth": "2", "Order": null, "Name": "New", "NameKr": null, "NameJp": null, "NameCn": null, "NameDe": null, "NameEs": null, "NameFr": null, "NameIt": null, "NameNl": null, "NameFromDB": null, "Brand": null, "Category": "women_new_arrivals_clothing", "GroupName": null, "Key": "root_new_arrivals_top_nav_alias", "ParentKey": "root", "HasLandingPage": false, "LandingPage
# ...

# %%
s3 = boto3.client('s3')
json_object = json.dumps(response.json())
client.put_object(
     Body=json.dumps(json_object),
     Bucket='forever21etl'
)

# %%
import snowflake.connector as sf
import pandas as pd

sf_creds = pd.read_csv("../ankur_accessKeys_SF.csv")
aws_creds = pd.read_csv("../ankur_accessKeys_s3.csv")
user = sf_creds["user"][0]
password = sf_creds["password"][0]
account = sf_creds["account"][0]
aws_key_id = aws_creds["Access key ID"][0]
aws_secret_key = aws_creds["Secret access key"][0]

# %%
statement = ''' CREATE OR REPLACE STAGE CLOTHING_STAGE
                URL = 's3://forever21etl/sales-records.csv'
                credentials = (aws_key_id = ''' + aws_key_id + '''
                   aws_secret_key = ''' + aws_secret_key + ''')
                file_format = csv_format;'''
statement
# Out:
# " CREATE OR REPLACE STAGE CLOTHING_STAGE\n                URL = 's3://forever21etl/sales-records.csv'\n                credentials = (aws_key_id = AKIAQ3EGVO6T6U7LBKPV\n                   aws_secret_key = 29rkJb4uNe7+tRvITH2CbZnTnGpbWyy2BRHiiP5K)\n                file_format = csv_format;"
